# %%
import torch

# %%
if torch.cuda.is_available():
    print("GPU is available")
else:
    print("GPU is not available")
# Out:
# GPU is available

# %%
# !python train.py --epochs 10 --workers 4 --device 0 --batch-size 8 --data data/Custom.yaml --img 640 640 --cfg cfg/training/yolov7.yaml --weights "yolov7-tiny.pt" --name tinyRun1
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
# train: WARNING: Ignoring corrupted image and/or label C:\Users\georg\Desktop\Yolo_data\Train\images\0001.png: duplicate labels
# train: WARNING: Ignoring corrupted image and/or label C:\Users\georg\Desktop\Yolo_data\Train\images\0002.png: duplicate labels
# train: WARNING: Ignoring corrupted image and/or label C:\Users\georg\Desktop\Yolo_data\Train\images\0004.png: duplicate labels
# train: WARNING: Ignoring corrupted image and/or label C:\Users\georg\Desktop\Yolo_data\Train\images\0005.png: duplicate labels
# train: WARNING: Ignoring corrupted image and/or label C:\Users\georg\Desktop\Yolo_data\Train\images\0006.png: duplicate labels
# train: WARNING: Ignoring corrupted image and/or label C:\Users\georg\Desktop\Yolo_data\Train\images\0007.png: duplicate labels
# train: WARNING: Ignoring corrupted image and/or label C:\Users\georg\Desktop\Yolo_data\Train\images\0009.png: duplicate labels
# ...

# %% [markdown]
# 1. 50 epochs at 50 freezed layers done
# 2. 100 epochs at 35 freezed layers done
# 3. 100 epochs at 25 freezed layers done
# 4. 100 epochs at 20 freezed layers done
# 5. 200 epochs at 0 freezed layers done
# 6. 150 epochs at 0 freezed higher data

# %% [markdown]
# #### inference

# %%
# !python detect.py --weights runs/train/App50e50f_last/weights/best.pt --conf 0.25 --img-size 640 --source inference/images/0011.png
# Out:
# Namespace(weights=['runs/train/App50e50f_last/weights/best.pt'], source='inference/images/0011.png', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 4 Forklifts, 4 Racks, 1 Floor, 28 Pallets, 6 Stillages, 2 iwhubs, 18 Dollys, Done. (12.9ms) Inference, (67.0ms) NMS
#  The image with the result is saved in: runs\detect\exp21\0011.png
# Done. (0.414s)
# YOLOR  v0.1-128-ga207844 torch 2.4.0+cu124 CUDA:0 (NVIDIA GeForce RTX 2060, 6143.6875MB)
#
# ...

# %%
import glob
from IPython.display import Image, display

# %%
i = 0
limit = 10000 # max images to print
for imageName in glob.glob('runs/detect/exp21/*.png'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1
