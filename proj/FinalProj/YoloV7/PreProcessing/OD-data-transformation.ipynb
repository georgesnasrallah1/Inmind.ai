# %%
import os
import numpy as np

# %%
def convert_bbox_to_yolo(size, bbox):
    """
    Convert bounding box from COCO format to YOLO format.
    COCO format: [xmin, ymin, xmax, ymax]
    YOLO format: [x_center, y_center, width, height] normalized to image size
    """
    dw = 1. / size[0]
    dh = 1. / size[1]
    x_center = (bbox[0] + bbox[2]) / 2.0 * dw
    y_center = (bbox[1] + bbox[3]) / 2.0 * dh
    width = (bbox[2] - bbox[0]) * dw
    height = (bbox[3] - bbox[1]) * dh
    return (x_center, y_center, width, height)

# %%
def convert_coco_to_yolo(input_folder, output_folder, image_size):
    """
    Convert COCO annotations saved in NumPy files to YOLO format and save as .txt files.

    :param input_folder: Folder containing the .npy files.
    :param output_folder: Folder to save the .txt files.
    :param image_size: Tuple of image (width, height).
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for npy_file in os.listdir(input_folder):
        if npy_file.endswith('.npy'):
            file_path = os.path.join(input_folder, npy_file)
            data = np.load(file_path, allow_pickle=True)

            yolo_annotations = []
            for item in data:
                class_id = int(item[0])
                xmin = item[1]
                ymin = item[2]
                xmax = item[3]
                ymax = item[4]

                bbox = convert_bbox_to_yolo(image_size, [xmin, ymin, xmax, ymax])
                yolo_annotation = f"{class_id} {bbox[0]} {bbox[1]} {bbox[2]} {bbox[3]}"
                yolo_annotations.append(yolo_annotation)

            # Save the YOLO annotations to a .txt file
            txt_file_name = npy_file.replace('.npy', '.txt')
            txt_file_path = os.path.join(output_folder, txt_file_name)

            with open(txt_file_path, 'w') as f:
                for annotation in yolo_annotations:
                    f.write(annotation + '\n')

            print(f"Converted {npy_file} to YOLO format and saved as {txt_file_name}")

# %%
input_folder = 'C:\\Users\\georg\\Desktop\\out-2'
output_folder = 'C:\\Users\\georg\\Desktop\\train_bbxs'
image_size = (1280, 720)

convert_coco_to_yolo(input_folder, output_folder, image_size)
# Out:
# Converted bounding_box_2d_tight_0000.npy to YOLO format and saved as bounding_box_2d_tight_0000.txt
# Converted bounding_box_2d_tight_0001.npy to YOLO format and saved as bounding_box_2d_tight_0001.txt
# Converted bounding_box_2d_tight_0002.npy to YOLO format and saved as bounding_box_2d_tight_0002.txt
# Converted bounding_box_2d_tight_0003.npy to YOLO format and saved as bounding_box_2d_tight_0003.txt
# Converted bounding_box_2d_tight_0004.npy to YOLO format and saved as bounding_box_2d_tight_0004.txt
# Converted bounding_box_2d_tight_0005.npy to YOLO format and saved as bounding_box_2d_tight_0005.txt
# Converted bounding_box_2d_tight_0006.npy to YOLO format and saved as bounding_box_2d_tight_0006.txt
# Converted bounding_box_2d_tight_0007.npy to YOLO format and saved as bounding_box_2d_tight_0007.txt
# Converted bounding_box_2d_tight_0008.npy to YOLO format and saved as bounding_box_2d_tight_0008.txt
# Converted bounding_box_2d_tight_0009.npy to YOLO format and saved as bounding_box_2d_tight_0009.txt
# Converted bounding_box_2d_tight_0010.npy to YOLO format and saved as bounding_box_2d_tight_0010.txt
# Converted bounding_box_2d_tight_0011.npy to YOLO format and saved as bounding_box_2d_tight_0011.txt
# Converted bounding_box_2d_tight_0012.npy to YOLO format and saved as bounding_box_2d_tight_0012.txt
# Converted bounding_box_2d_tight_0013.npy to YOLO format and saved as bounding_box_2d_tight_0013.txt
# Converted bounding_box_2d_tight_0014.npy to YOLO format and saved as bounding_box_2d_tight_0014.txt
# Converted bounding_box_2d_tight_0015.npy to YOLO format and saved as bounding_box_2d_tight_0015.txt
# Converted bounding_box_2d_tight_0016.npy to YOLO format and saved as bounding_box_2d_tight_0016.txt
# Converted bounding_box_2d_tight_0017.npy to YOLO format and saved as bounding_box_2d_tight_0017.txt
# Converted bounding_box_2d_tight_0018.npy to YOLO format and saved as bounding_box_2d_tight_0018.txt
# Converted bounding_box_2d_tight_0019.npy to YOLO format and saved as bounding_box_2d_tight_0019.txt
# Converted bounding_box_2d_tight_0020.npy to YOLO format and saved as bounding_box_2d_tight_0020.txt
# Converted bounding_box_2d_tight_0021.npy to YOLO format and saved as bounding_box_2d_tight_0021.txt
# Converted bounding_box_2d_tight_0022.npy to YOLO format and saved as bounding_box_2d_tight_0022.txt
# Converted bounding_box_2d_tight_0023.npy to YOLO format and saved as bounding_box_2d_tight_0023.txt
# Converted bounding_box_2d_tight_0024.npy to YOLO format and saved as bounding_box_2d_tight_0024.txt
# Converted bounding_box_2d_tight_0025.npy to YOLO format and saved as bounding_box_2d_tight_0025.txt
# Converted bounding_box_2d_tight_0026.npy to YOLO format and saved as bounding_box_2d_tight_0026.txt
# Converted bounding_box_2d_tight_0027.npy to YOLO format and saved as bounding_box_2d_tight_0027.txt
# Converted bounding_box_2d_tight_0028.npy to YOLO format and saved as bounding_box_2d_tight_0028.txt
# Converted bounding_box_2d_tight_0029.npy to YOLO format and saved as bounding_box_2d_tight_0029.txt
# Converted bounding_box_2d_tight_0030.npy to YOLO format and saved as bounding_box_2d_tight_0030.txt
# Converted bounding_box_2d_tight_0031.npy to YOLO format and saved as bounding_box_2d_tight_0031.txt
# Converted bounding_box_2d_tight_0032.npy to YOLO format and saved as bounding_box_2d_tight_0032.txt
# Converted bounding_box_2d_tight_0033.npy to YOLO format and saved as bounding_box_2d_tight_0033.txt
# Converted bounding_box_2d_tight_0034.npy to YOLO format and saved as bounding_box_2d_tight_0034.txt
# Converted bounding_box_2d_tight_0035.npy to YOLO format and saved as bounding_box_2d_tight_0035.txt
# Converted bounding_box_2d_tight_0036.npy to YOLO format and saved as bounding_box_2d_tight_0036.txt
# Converted bounding_box_2d_tight_0037.npy to YOLO format and saved as bounding_box_2d_tight_0037.txt
# Converted bounding_box_2d_tight_0038.npy to YOLO format and saved as bounding_box_2d_tight_0038.txt
# Converted bounding_box_2d_tight_0039.npy to YOLO format and saved as bounding_box_2d_tight_0039.txt
# Converted bounding_box_2d_tight_0040.npy to YOLO format and saved as bounding_box_2d_tight_0040.txt
# Converted bounding_box_2d_tight_0041.npy to YOLO format and saved as bounding_box_2d_tight_0041.txt
# Converted bounding_box_2d_tight_0042.npy to YOLO format and saved as bounding_box_2d_tight_0042.txt
# Converted bounding_box_2d_tight_0043.npy to YOLO format and saved as bounding_box_2d_tight_0043.txt
# Converted bounding_box_2d_tight_0044.npy to YOLO format and saved as bounding_box_2d_tight_0044.txt
# Converted bounding_box_2d_tight_0045.npy to YOLO format and saved as bounding_box_2d_tight_0045.txt
# Converted bounding_box_2d_tight_0046.npy to YOLO format and saved as bounding_box_2d_tight_0046.txt
# Converted bounding_box_2d_tight_0047.npy to YOLO format and saved as bounding_box_2d_tight_0047.txt
# Converted bounding_box_2d_tight_0048.npy to YOLO format and saved as bounding_box_2d_tight_0048.txt
# Converted bounding_box_2d_tight_0049.npy to YOLO format and saved as bounding_box_2d_tight_0049.txt
# Converted bounding_box_2d_tight_0050.npy to YOLO format and saved as bounding_box_2d_tight_0050.txt
# Converted bounding_box_2d_tight_0051.npy to YOLO format and saved as bounding_box_2d_tight_0051.txt
# Converted bounding_box_2d_tight_0052.npy to YOLO format and saved as bounding_box_2d_tight_0052.txt
# Converted bounding_box_2d_tight_0053.npy to YOLO format and saved as bounding_box_2d_tight_0053.txt
# Converted bounding_box_2d_tight_0054.npy to YOLO format and saved as bounding_box_2d_tight_0054.txt
# Converted bounding_box_2d_tight_0055.npy to YOLO format and saved as bounding_box_2d_tight_0055.txt
# Converted bounding_box_2d_tight_0056.npy to YOLO format and saved as bounding_box_2d_tight_0056.txt
# Converted bounding_box_2d_tight_0057.npy to YOLO format and saved as bounding_box_2d_tight_0057.txt
# Converted bounding_box_2d_tight_0058.npy to YOLO format and saved as bounding_box_2d_tight_0058.txt
# Converted bounding_box_2d_tight_0059.npy to YOLO format and saved as bounding_box_2d_tight_0059.txt
# Converted bounding_box_2d_tight_0060.npy to YOLO format and saved as bounding_box_2d_tight_0060.txt
# Converted bounding_box_2d_tight_0061.npy to YOLO format and saved as bounding_box_2d_tight_0061.txt
# Converted bounding_box_2d_tight_0062.npy to YOLO format and saved as bounding_box_2d_tight_0062.txt
# Converted bounding_box_2d_tight_0063.npy to YOLO format and saved as bounding_box_2d_tight_0063.txt
# Converted bounding_box_2d_tight_0064.npy to YOLO format and saved as bounding_box_2d_tight_0064.txt
# Converted bounding_box_2d_tight_0065.npy to YOLO format and saved as bounding_box_2d_tight_0065.txt
# Converted bounding_box_2d_tight_0066.npy to YOLO format and saved as bounding_box_2d_tight_0066.txt
# Converted bounding_box_2d_tight_0067.npy to YOLO format and saved as bounding_box_2d_tight_0067.txt
# Converted bounding_box_2d_tight_0068.npy to YOLO format and saved as bounding_box_2d_tight_0068.txt
# Converted bounding_box_2d_tight_0069.npy to YOLO format and saved as bounding_box_2d_tight_0069.txt
# Converted bounding_box_2d_tight_0070.npy to YOLO format and saved as bounding_box_2d_tight_0070.txt
# Converted bounding_box_2d_tight_0071.npy to YOLO format and saved as bounding_box_2d_tight_0071.txt
# Converted bounding_box_2d_tight_0072.npy to YOLO format and saved as bounding_box_2d_tight_0072.txt
# Converted bounding_box_2d_tight_0073.npy to YOLO format and saved as bounding_box_2d_tight_0073.txt
# Converted bounding_box_2d_tight_0074.npy to YOLO format and saved as bounding_box_2d_tight_0074.txt
# Converted bounding_box_2d_tight_0075.npy to YOLO format and saved as bounding_box_2d_tight_0075.txt
# Converted bounding_box_2d_tight_0076.npy to YOLO format and saved as bounding_box_2d_tight_0076.txt
# Converted bounding_box_2d_tight_0077.npy to YOLO format and saved as bounding_box_2d_tight_0077.txt
# Converted bounding_box_2d_tight_0078.npy to YOLO format and saved as bounding_box_2d_tight_0078.txt
# Converted bounding_box_2d_tight_0079.npy to YOLO format and saved as bounding_box_2d_tight_0079.txt
# Converted bounding_box_2d_tight_0080.npy to YOLO format and saved as bounding_box_2d_tight_0080.txt
# Converted bounding_box_2d_tight_0081.npy to YOLO format and saved as bounding_box_2d_tight_0081.txt
# Converted bounding_box_2d_tight_0082.npy to YOLO format and saved as bounding_box_2d_tight_0082.txt
# Converted bounding_box_2d_tight_0083.npy to YOLO format and saved as bounding_box_2d_tight_0083.txt
# Converted bounding_box_2d_tight_0084.npy to YOLO format and saved as bounding_box_2d_tight_0084.txt
# Converted bounding_box_2d_tight_0085.npy to YOLO format and saved as bounding_box_2d_tight_0085.txt
# Converted bounding_box_2d_tight_0086.npy to YOLO format and saved as bounding_box_2d_tight_0086.txt
# Converted bounding_box_2d_tight_0087.npy to YOLO format and saved as bounding_box_2d_tight_0087.txt
# Converted bounding_box_2d_tight_0088.npy to YOLO format and saved as bounding_box_2d_tight_0088.txt
# Converted bounding_box_2d_tight_0089.npy to YOLO format and saved as bounding_box_2d_tight_0089.txt
# Converted bounding_box_2d_tight_0090.npy to YOLO format and saved as bounding_box_2d_tight_0090.txt
# Converted bounding_box_2d_tight_0091.npy to YOLO format and saved as bounding_box_2d_tight_0091.txt
# Converted bounding_box_2d_tight_0092.npy to YOLO format and saved as bounding_box_2d_tight_0092.txt
# Converted bounding_box_2d_tight_0093.npy to YOLO format and saved as bounding_box_2d_tight_0093.txt
# Converted bounding_box_2d_tight_0094.npy to YOLO format and saved as bounding_box_2d_tight_0094.txt
# Converted bounding_box_2d_tight_0095.npy to YOLO format and saved as bounding_box_2d_tight_0095.txt
# Converted bounding_box_2d_tight_0096.npy to YOLO format and saved as bounding_box_2d_tight_0096.txt
# Converted bounding_box_2d_tight_0097.npy to YOLO format and saved as bounding_box_2d_tight_0097.txt
# Converted bounding_box_2d_tight_0098.npy to YOLO format and saved as bounding_box_2d_tight_0098.txt
# Converted bounding_box_2d_tight_0099.npy to YOLO format and saved as bounding_box_2d_tight_0099.txt
# Converted bounding_box_2d_tight_0100.npy to YOLO format and saved as bounding_box_2d_tight_0100.txt
# Converted bounding_box_2d_tight_0101.npy to YOLO format and saved as bounding_box_2d_tight_0101.txt
# Converted bounding_box_2d_tight_0102.npy to YOLO format and saved as bounding_box_2d_tight_0102.txt
# Converted bounding_box_2d_tight_0103.npy to YOLO format and saved as bounding_box_2d_tight_0103.txt
# Converted bounding_box_2d_tight_0104.npy to YOLO format and saved as bounding_box_2d_tight_0104.txt
# Converted bounding_box_2d_tight_0105.npy to YOLO format and saved as bounding_box_2d_tight_0105.txt
# Converted bounding_box_2d_tight_0106.npy to YOLO format and saved as bounding_box_2d_tight_0106.txt
# Converted bounding_box_2d_tight_0107.npy to YOLO format and saved as bounding_box_2d_tight_0107.txt
# Converted bounding_box_2d_tight_0108.npy to YOLO format and saved as bounding_box_2d_tight_0108.txt
# Converted bounding_box_2d_tight_0109.npy to YOLO format and saved as bounding_box_2d_tight_0109.txt
# Converted bounding_box_2d_tight_0110.npy to YOLO format and saved as bounding_box_2d_tight_0110.txt
# Converted bounding_box_2d_tight_0111.npy to YOLO format and saved as bounding_box_2d_tight_0111.txt
# Converted bounding_box_2d_tight_0112.npy to YOLO format and saved as bounding_box_2d_tight_0112.txt
# Converted bounding_box_2d_tight_0113.npy to YOLO format and saved as bounding_box_2d_tight_0113.txt
# Converted bounding_box_2d_tight_0114.npy to YOLO format and saved as bounding_box_2d_tight_0114.txt
# Converted bounding_box_2d_tight_0115.npy to YOLO format and saved as bounding_box_2d_tight_0115.txt
# Converted bounding_box_2d_tight_0116.npy to YOLO format and saved as bounding_box_2d_tight_0116.txt
# Converted bounding_box_2d_tight_0117.npy to YOLO format and saved as bounding_box_2d_tight_0117.txt
# Converted bounding_box_2d_tight_0118.npy to YOLO format and saved as bounding_box_2d_tight_0118.txt
# Converted bounding_box_2d_tight_0119.npy to YOLO format and saved as bounding_box_2d_tight_0119.txt
# Converted bounding_box_2d_tight_0120.npy to YOLO format and saved as bounding_box_2d_tight_0120.txt
# Converted bounding_box_2d_tight_0121.npy to YOLO format and saved as bounding_box_2d_tight_0121.txt
# Converted bounding_box_2d_tight_0122.npy to YOLO format and saved as bounding_box_2d_tight_0122.txt
# Converted bounding_box_2d_tight_0123.npy to YOLO format and saved as bounding_box_2d_tight_0123.txt
# Converted bounding_box_2d_tight_0124.npy to YOLO format and saved as bounding_box_2d_tight_0124.txt
# Converted bounding_box_2d_tight_0125.npy to YOLO format and saved as bounding_box_2d_tight_0125.txt
# Converted bounding_box_2d_tight_0126.npy to YOLO format and saved as bounding_box_2d_tight_0126.txt
# Converted bounding_box_2d_tight_0127.npy to YOLO format and saved as bounding_box_2d_tight_0127.txt
# Converted bounding_box_2d_tight_0128.npy to YOLO format and saved as bounding_box_2d_tight_0128.txt
# Converted bounding_box_2d_tight_0129.npy to YOLO format and saved as bounding_box_2d_tight_0129.txt
# Converted bounding_box_2d_tight_0130.npy to YOLO format and saved as bounding_box_2d_tight_0130.txt
# Converted bounding_box_2d_tight_0131.npy to YOLO format and saved as bounding_box_2d_tight_0131.txt
# Converted bounding_box_2d_tight_0132.npy to YOLO format and saved as bounding_box_2d_tight_0132.txt
# Converted bounding_box_2d_tight_0133.npy to YOLO format and saved as bounding_box_2d_tight_0133.txt
# Converted bounding_box_2d_tight_0134.npy to YOLO format and saved as bounding_box_2d_tight_0134.txt
# Converted bounding_box_2d_tight_0135.npy to YOLO format and saved as bounding_box_2d_tight_0135.txt
# Converted bounding_box_2d_tight_0136.npy to YOLO format and saved as bounding_box_2d_tight_0136.txt
# Converted bounding_box_2d_tight_0137.npy to YOLO format and saved as bounding_box_2d_tight_0137.txt
# Converted bounding_box_2d_tight_0138.npy to YOLO format and saved as bounding_box_2d_tight_0138.txt
# Converted bounding_box_2d_tight_0139.npy to YOLO format and saved as bounding_box_2d_tight_0139.txt
# Converted bounding_box_2d_tight_0140.npy to YOLO format and saved as bounding_box_2d_tight_0140.txt
# Converted bounding_box_2d_tight_0141.npy to YOLO format and saved as bounding_box_2d_tight_0141.txt
# Converted bounding_box_2d_tight_0142.npy to YOLO format and saved as bounding_box_2d_tight_0142.txt
# Converted bounding_box_2d_tight_0143.npy to YOLO format and saved as bounding_box_2d_tight_0143.txt
# Converted bounding_box_2d_tight_0144.npy to YOLO format and saved as bounding_box_2d_tight_0144.txt
# Converted bounding_box_2d_tight_0145.npy to YOLO format and saved as bounding_box_2d_tight_0145.txt
# Converted bounding_box_2d_tight_0146.npy to YOLO format and saved as bounding_box_2d_tight_0146.txt
# Converted bounding_box_2d_tight_0147.npy to YOLO format and saved as bounding_box_2d_tight_0147.txt
# Converted bounding_box_2d_tight_0148.npy to YOLO format and saved as bounding_box_2d_tight_0148.txt
# Converted bounding_box_2d_tight_0149.npy to YOLO format and saved as bounding_box_2d_tight_0149.txt
# Converted bounding_box_2d_tight_0150.npy to YOLO format and saved as bounding_box_2d_tight_0150.txt
# Converted bounding_box_2d_tight_0151.npy to YOLO format and saved as bounding_box_2d_tight_0151.txt
# Converted bounding_box_2d_tight_0152.npy to YOLO format and saved as bounding_box_2d_tight_0152.txt
# Converted bounding_box_2d_tight_0153.npy to YOLO format and saved as bounding_box_2d_tight_0153.txt
# Converted bounding_box_2d_tight_0154.npy to YOLO format and saved as bounding_box_2d_tight_0154.txt
# Converted bounding_box_2d_tight_0155.npy to YOLO format and saved as bounding_box_2d_tight_0155.txt
# Converted bounding_box_2d_tight_0156.npy to YOLO format and saved as bounding_box_2d_tight_0156.txt
# Converted bounding_box_2d_tight_0157.npy to YOLO format and saved as bounding_box_2d_tight_0157.txt
# Converted bounding_box_2d_tight_0158.npy to YOLO format and saved as bounding_box_2d_tight_0158.txt
# Converted bounding_box_2d_tight_0159.npy to YOLO format and saved as bounding_box_2d_tight_0159.txt
# Converted bounding_box_2d_tight_0160.npy to YOLO format and saved as bounding_box_2d_tight_0160.txt
# Converted bounding_box_2d_tight_0161.npy to YOLO format and saved as bounding_box_2d_tight_0161.txt
# Converted bounding_box_2d_tight_0162.npy to YOLO format and saved as bounding_box_2d_tight_0162.txt
# Converted bounding_box_2d_tight_0163.npy to YOLO format and saved as bounding_box_2d_tight_0163.txt
# Converted bounding_box_2d_tight_0164.npy to YOLO format and saved as bounding_box_2d_tight_0164.txt
# Converted bounding_box_2d_tight_0165.npy to YOLO format and saved as bounding_box_2d_tight_0165.txt
# Converted bounding_box_2d_tight_0166.npy to YOLO format and saved as bounding_box_2d_tight_0166.txt
# Converted bounding_box_2d_tight_0167.npy to YOLO format and saved as bounding_box_2d_tight_0167.txt
# Converted bounding_box_2d_tight_0168.npy to YOLO format and saved as bounding_box_2d_tight_0168.txt
# Converted bounding_box_2d_tight_0169.npy to YOLO format and saved as bounding_box_2d_tight_0169.txt
# Converted bounding_box_2d_tight_0170.npy to YOLO format and saved as bounding_box_2d_tight_0170.txt
# Converted bounding_box_2d_tight_0171.npy to YOLO format and saved as bounding_box_2d_tight_0171.txt
# Converted bounding_box_2d_tight_0172.npy to YOLO format and saved as bounding_box_2d_tight_0172.txt
# Converted bounding_box_2d_tight_0173.npy to YOLO format and saved as bounding_box_2d_tight_0173.txt
# Converted bounding_box_2d_tight_0174.npy to YOLO format and saved as bounding_box_2d_tight_0174.txt
# Converted bounding_box_2d_tight_0175.npy to YOLO format and saved as bounding_box_2d_tight_0175.txt
# Converted bounding_box_2d_tight_0176.npy to YOLO format and saved as bounding_box_2d_tight_0176.txt
# Converted bounding_box_2d_tight_0177.npy to YOLO format and saved as bounding_box_2d_tight_0177.txt
# Converted bounding_box_2d_tight_0178.npy to YOLO format and saved as bounding_box_2d_tight_0178.txt
# Converted bounding_box_2d_tight_0179.npy to YOLO format and saved as bounding_box_2d_tight_0179.txt
# Converted bounding_box_2d_tight_0180.npy to YOLO format and saved as bounding_box_2d_tight_0180.txt
# Converted bounding_box_2d_tight_0181.npy to YOLO format and saved as bounding_box_2d_tight_0181.txt
# Converted bounding_box_2d_tight_0182.npy to YOLO format and saved as bounding_box_2d_tight_0182.txt
# Converted bounding_box_2d_tight_0183.npy to YOLO format and saved as bounding_box_2d_tight_0183.txt
# Converted bounding_box_2d_tight_0184.npy to YOLO format and saved as bounding_box_2d_tight_0184.txt
# Converted bounding_box_2d_tight_0185.npy to YOLO format and saved as bounding_box_2d_tight_0185.txt
# Converted bounding_box_2d_tight_0186.npy to YOLO format and saved as bounding_box_2d_tight_0186.txt
# Converted bounding_box_2d_tight_0187.npy to YOLO format and saved as bounding_box_2d_tight_0187.txt
# Converted bounding_box_2d_tight_0188.npy to YOLO format and saved as bounding_box_2d_tight_0188.txt
# Converted bounding_box_2d_tight_0189.npy to YOLO format and saved as bounding_box_2d_tight_0189.txt
# Converted bounding_box_2d_tight_0190.npy to YOLO format and saved as bounding_box_2d_tight_0190.txt
# Converted bounding_box_2d_tight_0191.npy to YOLO format and saved as bounding_box_2d_tight_0191.txt
# Converted bounding_box_2d_tight_0192.npy to YOLO format and saved as bounding_box_2d_tight_0192.txt
# Converted bounding_box_2d_tight_0193.npy to YOLO format and saved as bounding_box_2d_tight_0193.txt
# Converted bounding_box_2d_tight_0194.npy to YOLO format and saved as bounding_box_2d_tight_0194.txt
# Converted bounding_box_2d_tight_0195.npy to YOLO format and saved as bounding_box_2d_tight_0195.txt
# Converted bounding_box_2d_tight_0196.npy to YOLO format and saved as bounding_box_2d_tight_0196.txt
# Converted bounding_box_2d_tight_0197.npy to YOLO format and saved as bounding_box_2d_tight_0197.txt
# Converted bounding_box_2d_tight_0198.npy to YOLO format and saved as bounding_box_2d_tight_0198.txt
# Converted bounding_box_2d_tight_0199.npy to YOLO format and saved as bounding_box_2d_tight_0199.txt
# Converted bounding_box_2d_tight_0200.npy to YOLO format and saved as bounding_box_2d_tight_0200.txt
# Converted bounding_box_2d_tight_0201.npy to YOLO format and saved as bounding_box_2d_tight_0201.txt
# Converted bounding_box_2d_tight_0202.npy to YOLO format and saved as bounding_box_2d_tight_0202.txt
# Converted bounding_box_2d_tight_0203.npy to YOLO format and saved as bounding_box_2d_tight_0203.txt
# Converted bounding_box_2d_tight_0204.npy to YOLO format and saved as bounding_box_2d_tight_0204.txt
# Converted bounding_box_2d_tight_0205.npy to YOLO format and saved as bounding_box_2d_tight_0205.txt
# Converted bounding_box_2d_tight_0206.npy to YOLO format and saved as bounding_box_2d_tight_0206.txt
# Converted bounding_box_2d_tight_0207.npy to YOLO format and saved as bounding_box_2d_tight_0207.txt
# Converted bounding_box_2d_tight_0208.npy to YOLO format and saved as bounding_box_2d_tight_0208.txt
# Converted bounding_box_2d_tight_0209.npy to YOLO format and saved as bounding_box_2d_tight_0209.txt
# Converted bounding_box_2d_tight_0210.npy to YOLO format and saved as bounding_box_2d_tight_0210.txt
# Converted bounding_box_2d_tight_0211.npy to YOLO format and saved as bounding_box_2d_tight_0211.txt
# Converted bounding_box_2d_tight_0212.npy to YOLO format and saved as bounding_box_2d_tight_0212.txt
# Converted bounding_box_2d_tight_0213.npy to YOLO format and saved as bounding_box_2d_tight_0213.txt
# Converted bounding_box_2d_tight_0214.npy to YOLO format and saved as bounding_box_2d_tight_0214.txt
# Converted bounding_box_2d_tight_0215.npy to YOLO format and saved as bounding_box_2d_tight_0215.txt
# Converted bounding_box_2d_tight_0216.npy to YOLO format and saved as bounding_box_2d_tight_0216.txt
# Converted bounding_box_2d_tight_0217.npy to YOLO format and saved as bounding_box_2d_tight_0217.txt
# Converted bounding_box_2d_tight_0218.npy to YOLO format and saved as bounding_box_2d_tight_0218.txt
# Converted bounding_box_2d_tight_0219.npy to YOLO format and saved as bounding_box_2d_tight_0219.txt
# Converted bounding_box_2d_tight_0220.npy to YOLO format and saved as bounding_box_2d_tight_0220.txt
# Converted bounding_box_2d_tight_0221.npy to YOLO format and saved as bounding_box_2d_tight_0221.txt
# Converted bounding_box_2d_tight_0222.npy to YOLO format and saved as bounding_box_2d_tight_0222.txt
# Converted bounding_box_2d_tight_0223.npy to YOLO format and saved as bounding_box_2d_tight_0223.txt
# Converted bounding_box_2d_tight_0224.npy to YOLO format and saved as bounding_box_2d_tight_0224.txt
# Converted bounding_box_2d_tight_0225.npy to YOLO format and saved as bounding_box_2d_tight_0225.txt
# Converted bounding_box_2d_tight_0226.npy to YOLO format and saved as bounding_box_2d_tight_0226.txt
# Converted bounding_box_2d_tight_0227.npy to YOLO format and saved as bounding_box_2d_tight_0227.txt
# Converted bounding_box_2d_tight_0228.npy to YOLO format and saved as bounding_box_2d_tight_0228.txt
# Converted bounding_box_2d_tight_0229.npy to YOLO format and saved as bounding_box_2d_tight_0229.txt
# Converted bounding_box_2d_tight_0230.npy to YOLO format and saved as bounding_box_2d_tight_0230.txt
# Converted bounding_box_2d_tight_0231.npy to YOLO format and saved as bounding_box_2d_tight_0231.txt
# Converted bounding_box_2d_tight_0232.npy to YOLO format and saved as bounding_box_2d_tight_0232.txt
# Converted bounding_box_2d_tight_0233.npy to YOLO format and saved as bounding_box_2d_tight_0233.txt
# Converted bounding_box_2d_tight_0234.npy to YOLO format and saved as bounding_box_2d_tight_0234.txt
# Converted bounding_box_2d_tight_0235.npy to YOLO format and saved as bounding_box_2d_tight_0235.txt
# Converted bounding_box_2d_tight_0236.npy to YOLO format and saved as bounding_box_2d_tight_0236.txt
# Converted bounding_box_2d_tight_0237.npy to YOLO format and saved as bounding_box_2d_tight_0237.txt
# Converted bounding_box_2d_tight_0238.npy to YOLO format and saved as bounding_box_2d_tight_0238.txt
# Converted bounding_box_2d_tight_0239.npy to YOLO format and saved as bounding_box_2d_tight_0239.txt
# Converted bounding_box_2d_tight_0240.npy to YOLO format and saved as bounding_box_2d_tight_0240.txt
# Converted bounding_box_2d_tight_0241.npy to YOLO format and saved as bounding_box_2d_tight_0241.txt
# Converted bounding_box_2d_tight_0242.npy to YOLO format and saved as bounding_box_2d_tight_0242.txt
# Converted bounding_box_2d_tight_0243.npy to YOLO format and saved as bounding_box_2d_tight_0243.txt
# Converted bounding_box_2d_tight_0244.npy to YOLO format and saved as bounding_box_2d_tight_0244.txt
# Converted bounding_box_2d_tight_0245.npy to YOLO format and saved as bounding_box_2d_tight_0245.txt
# Converted bounding_box_2d_tight_0246.npy to YOLO format and saved as bounding_box_2d_tight_0246.txt
# Converted bounding_box_2d_tight_0247.npy to YOLO format and saved as bounding_box_2d_tight_0247.txt
# Converted bounding_box_2d_tight_0248.npy to YOLO format and saved as bounding_box_2d_tight_0248.txt
# Converted bounding_box_2d_tight_0249.npy to YOLO format and saved as bounding_box_2d_tight_0249.txt
# Converted bounding_box_2d_tight_0250.npy to YOLO format and saved as bounding_box_2d_tight_0250.txt
# Converted bounding_box_2d_tight_0251.npy to YOLO format and saved as bounding_box_2d_tight_0251.txt
# Converted bounding_box_2d_tight_0252.npy to YOLO format and saved as bounding_box_2d_tight_0252.txt
# Converted bounding_box_2d_tight_0253.npy to YOLO format and saved as bounding_box_2d_tight_0253.txt
# Converted bounding_box_2d_tight_0254.npy to YOLO format and saved as bounding_box_2d_tight_0254.txt
# Converted bounding_box_2d_tight_0255.npy to YOLO format and saved as bounding_box_2d_tight_0255.txt
# Converted bounding_box_2d_tight_0256.npy to YOLO format and saved as bounding_box_2d_tight_0256.txt
# Converted bounding_box_2d_tight_0257.npy to YOLO format and saved as bounding_box_2d_tight_0257.txt
# Converted bounding_box_2d_tight_0258.npy to YOLO format and saved as bounding_box_2d_tight_0258.txt
# Converted bounding_box_2d_tight_0259.npy to YOLO format and saved as bounding_box_2d_tight_0259.txt
# Converted bounding_box_2d_tight_0260.npy to YOLO format and saved as bounding_box_2d_tight_0260.txt
# Converted bounding_box_2d_tight_0261.npy to YOLO format and saved as bounding_box_2d_tight_0261.txt
# Converted bounding_box_2d_tight_0262.npy to YOLO format and saved as bounding_box_2d_tight_0262.txt
# Converted bounding_box_2d_tight_0263.npy to YOLO format and saved as bounding_box_2d_tight_0263.txt
# Converted bounding_box_2d_tight_0264.npy to YOLO format and saved as bounding_box_2d_tight_0264.txt
# Converted bounding_box_2d_tight_0265.npy to YOLO format and saved as bounding_box_2d_tight_0265.txt
# Converted bounding_box_2d_tight_0266.npy to YOLO format and saved as bounding_box_2d_tight_0266.txt
# Converted bounding_box_2d_tight_0267.npy to YOLO format and saved as bounding_box_2d_tight_0267.txt
# Converted bounding_box_2d_tight_0268.npy to YOLO format and saved as bounding_box_2d_tight_0268.txt
# Converted bounding_box_2d_tight_0269.npy to YOLO format and saved as bounding_box_2d_tight_0269.txt
# Converted bounding_box_2d_tight_0270.npy to YOLO format and saved as bounding_box_2d_tight_0270.txt
# Converted bounding_box_2d_tight_0271.npy to YOLO format and saved as bounding_box_2d_tight_0271.txt
# Converted bounding_box_2d_tight_0272.npy to YOLO format and saved as bounding_box_2d_tight_0272.txt
# Converted bounding_box_2d_tight_0273.npy to YOLO format and saved as bounding_box_2d_tight_0273.txt
# Converted bounding_box_2d_tight_0274.npy to YOLO format and saved as bounding_box_2d_tight_0274.txt
# Converted bounding_box_2d_tight_0275.npy to YOLO format and saved as bounding_box_2d_tight_0275.txt
# Converted bounding_box_2d_tight_0276.npy to YOLO format and saved as bounding_box_2d_tight_0276.txt
# Converted bounding_box_2d_tight_0277.npy to YOLO format and saved as bounding_box_2d_tight_0277.txt
# Converted bounding_box_2d_tight_0278.npy to YOLO format and saved as bounding_box_2d_tight_0278.txt
# Converted bounding_box_2d_tight_0279.npy to YOLO format and saved as bounding_box_2d_tight_0279.txt
# Converted bounding_box_2d_tight_0280.npy to YOLO format and saved as bounding_box_2d_tight_0280.txt
# Converted bounding_box_2d_tight_0281.npy to YOLO format and saved as bounding_box_2d_tight_0281.txt
# Converted bounding_box_2d_tight_0282.npy to YOLO format and saved as bounding_box_2d_tight_0282.txt
# Converted bounding_box_2d_tight_0283.npy to YOLO format and saved as bounding_box_2d_tight_0283.txt
# Converted bounding_box_2d_tight_0284.npy to YOLO format and saved as bounding_box_2d_tight_0284.txt
# Converted bounding_box_2d_tight_0285.npy to YOLO format and saved as bounding_box_2d_tight_0285.txt
# Converted bounding_box_2d_tight_0286.npy to YOLO format and saved as bounding_box_2d_tight_0286.txt
# Converted bounding_box_2d_tight_0287.npy to YOLO format and saved as bounding_box_2d_tight_0287.txt
# Converted bounding_box_2d_tight_0288.npy to YOLO format and saved as bounding_box_2d_tight_0288.txt
# Converted bounding_box_2d_tight_0289.npy to YOLO format and saved as bounding_box_2d_tight_0289.txt
# Converted bounding_box_2d_tight_0290.npy to YOLO format and saved as bounding_box_2d_tight_0290.txt
# Converted bounding_box_2d_tight_0291.npy to YOLO format and saved as bounding_box_2d_tight_0291.txt
# Converted bounding_box_2d_tight_0292.npy to YOLO format and saved as bounding_box_2d_tight_0292.txt
# Converted bounding_box_2d_tight_0293.npy to YOLO format and saved as bounding_box_2d_tight_0293.txt
# Converted bounding_box_2d_tight_0294.npy to YOLO format and saved as bounding_box_2d_tight_0294.txt
# Converted bounding_box_2d_tight_0295.npy to YOLO format and saved as bounding_box_2d_tight_0295.txt
# Converted bounding_box_2d_tight_0296.npy to YOLO format and saved as bounding_box_2d_tight_0296.txt
# Converted bounding_box_2d_tight_0297.npy to YOLO format and saved as bounding_box_2d_tight_0297.txt
# Converted bounding_box_2d_tight_0298.npy to YOLO format and saved as bounding_box_2d_tight_0298.txt
# Converted bounding_box_2d_tight_0299.npy to YOLO format and saved as bounding_box_2d_tight_0299.txt
# Converted bounding_box_2d_tight_0300.npy to YOLO format and saved as bounding_box_2d_tight_0300.txt
# Converted bounding_box_2d_tight_0301.npy to YOLO format and saved as bounding_box_2d_tight_0301.txt
# Converted bounding_box_2d_tight_0302.npy to YOLO format and saved as bounding_box_2d_tight_0302.txt
# Converted bounding_box_2d_tight_0303.npy to YOLO format and saved as bounding_box_2d_tight_0303.txt
# Converted bounding_box_2d_tight_0304.npy to YOLO format and saved as bounding_box_2d_tight_0304.txt
# Converted bounding_box_2d_tight_0305.npy to YOLO format and saved as bounding_box_2d_tight_0305.txt
# Converted bounding_box_2d_tight_0306.npy to YOLO format and saved as bounding_box_2d_tight_0306.txt
# Converted bounding_box_2d_tight_0307.npy to YOLO format and saved as bounding_box_2d_tight_0307.txt
# Converted bounding_box_2d_tight_0308.npy to YOLO format and saved as bounding_box_2d_tight_0308.txt
# Converted bounding_box_2d_tight_0309.npy to YOLO format and saved as bounding_box_2d_tight_0309.txt
# Converted bounding_box_2d_tight_0310.npy to YOLO format and saved as bounding_box_2d_tight_0310.txt
# Converted bounding_box_2d_tight_0311.npy to YOLO format and saved as bounding_box_2d_tight_0311.txt
# Converted bounding_box_2d_tight_0312.npy to YOLO format and saved as bounding_box_2d_tight_0312.txt
# Converted bounding_box_2d_tight_0313.npy to YOLO format and saved as bounding_box_2d_tight_0313.txt
# Converted bounding_box_2d_tight_0314.npy to YOLO format and saved as bounding_box_2d_tight_0314.txt
# Converted bounding_box_2d_tight_0315.npy to YOLO format and saved as bounding_box_2d_tight_0315.txt
# Converted bounding_box_2d_tight_0316.npy to YOLO format and saved as bounding_box_2d_tight_0316.txt
# Converted bounding_box_2d_tight_0317.npy to YOLO format and saved as bounding_box_2d_tight_0317.txt
# Converted bounding_box_2d_tight_0318.npy to YOLO format and saved as bounding_box_2d_tight_0318.txt
# Converted bounding_box_2d_tight_0319.npy to YOLO format and saved as bounding_box_2d_tight_0319.txt
# Converted bounding_box_2d_tight_0320.npy to YOLO format and saved as bounding_box_2d_tight_0320.txt
# Converted bounding_box_2d_tight_0321.npy to YOLO format and saved as bounding_box_2d_tight_0321.txt
# Converted bounding_box_2d_tight_0322.npy to YOLO format and saved as bounding_box_2d_tight_0322.txt
# Converted bounding_box_2d_tight_0323.npy to YOLO format and saved as bounding_box_2d_tight_0323.txt
# Converted bounding_box_2d_tight_0324.npy to YOLO format and saved as bounding_box_2d_tight_0324.txt
# Converted bounding_box_2d_tight_0325.npy to YOLO format and saved as bounding_box_2d_tight_0325.txt
# Converted bounding_box_2d_tight_0326.npy to YOLO format and saved as bounding_box_2d_tight_0326.txt
# Converted bounding_box_2d_tight_0327.npy to YOLO format and saved as bounding_box_2d_tight_0327.txt
# Converted bounding_box_2d_tight_0328.npy to YOLO format and saved as bounding_box_2d_tight_0328.txt
# Converted bounding_box_2d_tight_0329.npy to YOLO format and saved as bounding_box_2d_tight_0329.txt
# Converted bounding_box_2d_tight_0330.npy to YOLO format and saved as bounding_box_2d_tight_0330.txt
# Converted bounding_box_2d_tight_0331.npy to YOLO format and saved as bounding_box_2d_tight_0331.txt
# Converted bounding_box_2d_tight_0332.npy to YOLO format and saved as bounding_box_2d_tight_0332.txt
# Converted bounding_box_2d_tight_0333.npy to YOLO format and saved as bounding_box_2d_tight_0333.txt
# Converted bounding_box_2d_tight_0334.npy to YOLO format and saved as bounding_box_2d_tight_0334.txt
# Converted bounding_box_2d_tight_0335.npy to YOLO format and saved as bounding_box_2d_tight_0335.txt
# Converted bounding_box_2d_tight_0336.npy to YOLO format and saved as bounding_box_2d_tight_0336.txt
# Converted bounding_box_2d_tight_0337.npy to YOLO format and saved as bounding_box_2d_tight_0337.txt
# Converted bounding_box_2d_tight_0338.npy to YOLO format and saved as bounding_box_2d_tight_0338.txt
# Converted bounding_box_2d_tight_0339.npy to YOLO format and saved as bounding_box_2d_tight_0339.txt
# Converted bounding_box_2d_tight_0340.npy to YOLO format and saved as bounding_box_2d_tight_0340.txt
# Converted bounding_box_2d_tight_0341.npy to YOLO format and saved as bounding_box_2d_tight_0341.txt
# Converted bounding_box_2d_tight_0342.npy to YOLO format and saved as bounding_box_2d_tight_0342.txt
# Converted bounding_box_2d_tight_0343.npy to YOLO format and saved as bounding_box_2d_tight_0343.txt
# Converted bounding_box_2d_tight_0344.npy to YOLO format and saved as bounding_box_2d_tight_0344.txt
# Converted bounding_box_2d_tight_0345.npy to YOLO format and saved as bounding_box_2d_tight_0345.txt
# Converted bounding_box_2d_tight_0346.npy to YOLO format and saved as bounding_box_2d_tight_0346.txt
# Converted bounding_box_2d_tight_0347.npy to YOLO format and saved as bounding_box_2d_tight_0347.txt
# Converted bounding_box_2d_tight_0348.npy to YOLO format and saved as bounding_box_2d_tight_0348.txt
# Converted bounding_box_2d_tight_0349.npy to YOLO format and saved as bounding_box_2d_tight_0349.txt
# Converted bounding_box_2d_tight_0350.npy to YOLO format and saved as bounding_box_2d_tight_0350.txt
# Converted bounding_box_2d_tight_0351.npy to YOLO format and saved as bounding_box_2d_tight_0351.txt
# Converted bounding_box_2d_tight_0352.npy to YOLO format and saved as bounding_box_2d_tight_0352.txt
# Converted bounding_box_2d_tight_0353.npy to YOLO format and saved as bounding_box_2d_tight_0353.txt
# Converted bounding_box_2d_tight_0354.npy to YOLO format and saved as bounding_box_2d_tight_0354.txt
# Converted bounding_box_2d_tight_0355.npy to YOLO format and saved as bounding_box_2d_tight_0355.txt
# Converted bounding_box_2d_tight_0356.npy to YOLO format and saved as bounding_box_2d_tight_0356.txt
# Converted bounding_box_2d_tight_0357.npy to YOLO format and saved as bounding_box_2d_tight_0357.txt
# Converted bounding_box_2d_tight_0358.npy to YOLO format and saved as bounding_box_2d_tight_0358.txt
# Converted bounding_box_2d_tight_0359.npy to YOLO format and saved as bounding_box_2d_tight_0359.txt
# Converted bounding_box_2d_tight_0360.npy to YOLO format and saved as bounding_box_2d_tight_0360.txt
# Converted bounding_box_2d_tight_0361.npy to YOLO format and saved as bounding_box_2d_tight_0361.txt
# Converted bounding_box_2d_tight_0362.npy to YOLO format and saved as bounding_box_2d_tight_0362.txt
# Converted bounding_box_2d_tight_0363.npy to YOLO format and saved as bounding_box_2d_tight_0363.txt
# Converted bounding_box_2d_tight_0364.npy to YOLO format and saved as bounding_box_2d_tight_0364.txt
# Converted bounding_box_2d_tight_0365.npy to YOLO format and saved as bounding_box_2d_tight_0365.txt
# Converted bounding_box_2d_tight_0366.npy to YOLO format and saved as bounding_box_2d_tight_0366.txt
# Converted bounding_box_2d_tight_0367.npy to YOLO format and saved as bounding_box_2d_tight_0367.txt
# Converted bounding_box_2d_tight_0368.npy to YOLO format and saved as bounding_box_2d_tight_0368.txt
# Converted bounding_box_2d_tight_0369.npy to YOLO format and saved as bounding_box_2d_tight_0369.txt
# Converted bounding_box_2d_tight_0370.npy to YOLO format and saved as bounding_box_2d_tight_0370.txt
# Converted bounding_box_2d_tight_0371.npy to YOLO format and saved as bounding_box_2d_tight_0371.txt
# Converted bounding_box_2d_tight_0372.npy to YOLO format and saved as bounding_box_2d_tight_0372.txt
# Converted bounding_box_2d_tight_0373.npy to YOLO format and saved as bounding_box_2d_tight_0373.txt
# Converted bounding_box_2d_tight_0374.npy to YOLO format and saved as bounding_box_2d_tight_0374.txt
# Converted bounding_box_2d_tight_0375.npy to YOLO format and saved as bounding_box_2d_tight_0375.txt
# Converted bounding_box_2d_tight_0376.npy to YOLO format and saved as bounding_box_2d_tight_0376.txt
# Converted bounding_box_2d_tight_0377.npy to YOLO format and saved as bounding_box_2d_tight_0377.txt
# Converted bounding_box_2d_tight_0378.npy to YOLO format and saved as bounding_box_2d_tight_0378.txt
# Converted bounding_box_2d_tight_0379.npy to YOLO format and saved as bounding_box_2d_tight_0379.txt
# Converted bounding_box_2d_tight_0380.npy to YOLO format and saved as bounding_box_2d_tight_0380.txt
# Converted bounding_box_2d_tight_0381.npy to YOLO format and saved as bounding_box_2d_tight_0381.txt
# Converted bounding_box_2d_tight_0382.npy to YOLO format and saved as bounding_box_2d_tight_0382.txt
# Converted bounding_box_2d_tight_0383.npy to YOLO format and saved as bounding_box_2d_tight_0383.txt
# Converted bounding_box_2d_tight_0384.npy to YOLO format and saved as bounding_box_2d_tight_0384.txt
# Converted bounding_box_2d_tight_0385.npy to YOLO format and saved as bounding_box_2d_tight_0385.txt
# Converted bounding_box_2d_tight_0386.npy to YOLO format and saved as bounding_box_2d_tight_0386.txt
# Converted bounding_box_2d_tight_0387.npy to YOLO format and saved as bounding_box_2d_tight_0387.txt
# Converted bounding_box_2d_tight_0388.npy to YOLO format and saved as bounding_box_2d_tight_0388.txt
# Converted bounding_box_2d_tight_0389.npy to YOLO format and saved as bounding_box_2d_tight_0389.txt
# Converted bounding_box_2d_tight_0390.npy to YOLO format and saved as bounding_box_2d_tight_0390.txt
# Converted bounding_box_2d_tight_0391.npy to YOLO format and saved as bounding_box_2d_tight_0391.txt
# Converted bounding_box_2d_tight_0392.npy to YOLO format and saved as bounding_box_2d_tight_0392.txt
# Converted bounding_box_2d_tight_0393.npy to YOLO format and saved as bounding_box_2d_tight_0393.txt
# Converted bounding_box_2d_tight_0394.npy to YOLO format and saved as bounding_box_2d_tight_0394.txt
# Converted bounding_box_2d_tight_0395.npy to YOLO format and saved as bounding_box_2d_tight_0395.txt
# Converted bounding_box_2d_tight_0396.npy to YOLO format and saved as bounding_box_2d_tight_0396.txt
# Converted bounding_box_2d_tight_0397.npy to YOLO format and saved as bounding_box_2d_tight_0397.txt
# Converted bounding_box_2d_tight_0398.npy to YOLO format and saved as bounding_box_2d_tight_0398.txt
# Converted bounding_box_2d_tight_0399.npy to YOLO format and saved as bounding_box_2d_tight_0399.txt
# Converted bounding_box_2d_tight_0400.npy to YOLO format and saved as bounding_box_2d_tight_0400.txt
# Converted bounding_box_2d_tight_0401.npy to YOLO format and saved as bounding_box_2d_tight_0401.txt
# Converted bounding_box_2d_tight_0402.npy to YOLO format and saved as bounding_box_2d_tight_0402.txt
# Converted bounding_box_2d_tight_0403.npy to YOLO format and saved as bounding_box_2d_tight_0403.txt
# Converted bounding_box_2d_tight_0404.npy to YOLO format and saved as bounding_box_2d_tight_0404.txt
# Converted bounding_box_2d_tight_0405.npy to YOLO format and saved as bounding_box_2d_tight_0405.txt
# Converted bounding_box_2d_tight_0406.npy to YOLO format and saved as bounding_box_2d_tight_0406.txt
# Converted bounding_box_2d_tight_0407.npy to YOLO format and saved as bounding_box_2d_tight_0407.txt
# Converted bounding_box_2d_tight_0408.npy to YOLO format and saved as bounding_box_2d_tight_0408.txt
# Converted bounding_box_2d_tight_0409.npy to YOLO format and saved as bounding_box_2d_tight_0409.txt
# Converted bounding_box_2d_tight_0410.npy to YOLO format and saved as bounding_box_2d_tight_0410.txt
# Converted bounding_box_2d_tight_0411.npy to YOLO format and saved as bounding_box_2d_tight_0411.txt
# Converted bounding_box_2d_tight_0412.npy to YOLO format and saved as bounding_box_2d_tight_0412.txt
# Converted bounding_box_2d_tight_0413.npy to YOLO format and saved as bounding_box_2d_tight_0413.txt
# Converted bounding_box_2d_tight_0414.npy to YOLO format and saved as bounding_box_2d_tight_0414.txt
# Converted bounding_box_2d_tight_0415.npy to YOLO format and saved as bounding_box_2d_tight_0415.txt
# Converted bounding_box_2d_tight_0416.npy to YOLO format and saved as bounding_box_2d_tight_0416.txt
# Converted bounding_box_2d_tight_0417.npy to YOLO format and saved as bounding_box_2d_tight_0417.txt
# Converted bounding_box_2d_tight_0418.npy to YOLO format and saved as bounding_box_2d_tight_0418.txt
# Converted bounding_box_2d_tight_0419.npy to YOLO format and saved as bounding_box_2d_tight_0419.txt
# Converted bounding_box_2d_tight_0420.npy to YOLO format and saved as bounding_box_2d_tight_0420.txt
# Converted bounding_box_2d_tight_0421.npy to YOLO format and saved as bounding_box_2d_tight_0421.txt
# Converted bounding_box_2d_tight_0422.npy to YOLO format and saved as bounding_box_2d_tight_0422.txt
# Converted bounding_box_2d_tight_0423.npy to YOLO format and saved as bounding_box_2d_tight_0423.txt
# Converted bounding_box_2d_tight_0424.npy to YOLO format and saved as bounding_box_2d_tight_0424.txt
# Converted bounding_box_2d_tight_0425.npy to YOLO format and saved as bounding_box_2d_tight_0425.txt
# Converted bounding_box_2d_tight_0426.npy to YOLO format and saved as bounding_box_2d_tight_0426.txt
# Converted bounding_box_2d_tight_0427.npy to YOLO format and saved as bounding_box_2d_tight_0427.txt
# Converted bounding_box_2d_tight_0428.npy to YOLO format and saved as bounding_box_2d_tight_0428.txt
# Converted bounding_box_2d_tight_0429.npy to YOLO format and saved as bounding_box_2d_tight_0429.txt
# Converted bounding_box_2d_tight_0430.npy to YOLO format and saved as bounding_box_2d_tight_0430.txt
# Converted bounding_box_2d_tight_0431.npy to YOLO format and saved as bounding_box_2d_tight_0431.txt
# Converted bounding_box_2d_tight_0432.npy to YOLO format and saved as bounding_box_2d_tight_0432.txt
# Converted bounding_box_2d_tight_0433.npy to YOLO format and saved as bounding_box_2d_tight_0433.txt
# Converted bounding_box_2d_tight_0434.npy to YOLO format and saved as bounding_box_2d_tight_0434.txt
# Converted bounding_box_2d_tight_0435.npy to YOLO format and saved as bounding_box_2d_tight_0435.txt
# Converted bounding_box_2d_tight_0436.npy to YOLO format and saved as bounding_box_2d_tight_0436.txt
# Converted bounding_box_2d_tight_0437.npy to YOLO format and saved as bounding_box_2d_tight_0437.txt
# Converted bounding_box_2d_tight_0438.npy to YOLO format and saved as bounding_box_2d_tight_0438.txt
# Converted bounding_box_2d_tight_0439.npy to YOLO format and saved as bounding_box_2d_tight_0439.txt
# Converted bounding_box_2d_tight_0440.npy to YOLO format and saved as bounding_box_2d_tight_0440.txt
# Converted bounding_box_2d_tight_0441.npy to YOLO format and saved as bounding_box_2d_tight_0441.txt
# Converted bounding_box_2d_tight_0442.npy to YOLO format and saved as bounding_box_2d_tight_0442.txt
# Converted bounding_box_2d_tight_0443.npy to YOLO format and saved as bounding_box_2d_tight_0443.txt
# Converted bounding_box_2d_tight_0444.npy to YOLO format and saved as bounding_box_2d_tight_0444.txt
# Converted bounding_box_2d_tight_0445.npy to YOLO format and saved as bounding_box_2d_tight_0445.txt
# Converted bounding_box_2d_tight_0446.npy to YOLO format and saved as bounding_box_2d_tight_0446.txt
# Converted bounding_box_2d_tight_0447.npy to YOLO format and saved as bounding_box_2d_tight_0447.txt
# Converted bounding_box_2d_tight_0448.npy to YOLO format and saved as bounding_box_2d_tight_0448.txt
# Converted bounding_box_2d_tight_0449.npy to YOLO format and saved as bounding_box_2d_tight_0449.txt
# Converted bounding_box_2d_tight_0450.npy to YOLO format and saved as bounding_box_2d_tight_0450.txt
# Converted bounding_box_2d_tight_0451.npy to YOLO format and saved as bounding_box_2d_tight_0451.txt
# Converted bounding_box_2d_tight_0452.npy to YOLO format and saved as bounding_box_2d_tight_0452.txt
# Converted bounding_box_2d_tight_0453.npy to YOLO format and saved as bounding_box_2d_tight_0453.txt
# Converted bounding_box_2d_tight_0454.npy to YOLO format and saved as bounding_box_2d_tight_0454.txt
# Converted bounding_box_2d_tight_0455.npy to YOLO format and saved as bounding_box_2d_tight_0455.txt
# Converted bounding_box_2d_tight_0456.npy to YOLO format and saved as bounding_box_2d_tight_0456.txt
# Converted bounding_box_2d_tight_0457.npy to YOLO format and saved as bounding_box_2d_tight_0457.txt
# Converted bounding_box_2d_tight_0458.npy to YOLO format and saved as bounding_box_2d_tight_0458.txt
# Converted bounding_box_2d_tight_0459.npy to YOLO format and saved as bounding_box_2d_tight_0459.txt
# Converted bounding_box_2d_tight_0460.npy to YOLO format and saved as bounding_box_2d_tight_0460.txt
# Converted bounding_box_2d_tight_0461.npy to YOLO format and saved as bounding_box_2d_tight_0461.txt
# Converted bounding_box_2d_tight_0462.npy to YOLO format and saved as bounding_box_2d_tight_0462.txt
# Converted bounding_box_2d_tight_0463.npy to YOLO format and saved as bounding_box_2d_tight_0463.txt
# Converted bounding_box_2d_tight_0464.npy to YOLO format and saved as bounding_box_2d_tight_0464.txt
# Converted bounding_box_2d_tight_0465.npy to YOLO format and saved as bounding_box_2d_tight_0465.txt
# Converted bounding_box_2d_tight_0466.npy to YOLO format and saved as bounding_box_2d_tight_0466.txt
# Converted bounding_box_2d_tight_0467.npy to YOLO format and saved as bounding_box_2d_tight_0467.txt
# Converted bounding_box_2d_tight_0468.npy to YOLO format and saved as bounding_box_2d_tight_0468.txt
# Converted bounding_box_2d_tight_0469.npy to YOLO format and saved as bounding_box_2d_tight_0469.txt
# Converted bounding_box_2d_tight_0470.npy to YOLO format and saved as bounding_box_2d_tight_0470.txt
# Converted bounding_box_2d_tight_0471.npy to YOLO format and saved as bounding_box_2d_tight_0471.txt
# Converted bounding_box_2d_tight_0472.npy to YOLO format and saved as bounding_box_2d_tight_0472.txt
# Converted bounding_box_2d_tight_0473.npy to YOLO format and saved as bounding_box_2d_tight_0473.txt
# Converted bounding_box_2d_tight_0474.npy to YOLO format and saved as bounding_box_2d_tight_0474.txt
# Converted bounding_box_2d_tight_0475.npy to YOLO format and saved as bounding_box_2d_tight_0475.txt
# Converted bounding_box_2d_tight_0476.npy to YOLO format and saved as bounding_box_2d_tight_0476.txt
# Converted bounding_box_2d_tight_0477.npy to YOLO format and saved as bounding_box_2d_tight_0477.txt
# Converted bounding_box_2d_tight_0478.npy to YOLO format and saved as bounding_box_2d_tight_0478.txt
# Converted bounding_box_2d_tight_0479.npy to YOLO format and saved as bounding_box_2d_tight_0479.txt
# ...
# Converted bounding_box_2d_tight_0840.npy to YOLO format and saved as bounding_box_2d_tight_0840.txt
# Converted bounding_box_2d_tight_0841.npy to YOLO format and saved as bounding_box_2d_tight_0841.txt
# Converted bounding_box_2d_tight_0842.npy to YOLO format and saved as bounding_box_2d_tight_0842.txt
# Converted bounding_box_2d_tight_0843.npy to YOLO format and saved as bounding_box_2d_tight_0843.txt
# Converted bounding_box_2d_tight_0844.npy to YOLO format and saved as bounding_box_2d_tight_0844.txt
# Converted bounding_box_2d_tight_0845.npy to YOLO format and saved as bounding_box_2d_tight_0845.txt
# Converted bounding_box_2d_tight_0846.npy to YOLO format and saved as bounding_box_2d_tight_0846.txt
# Converted bounding_box_2d_tight_0847.npy to YOLO format and saved as bounding_box_2d_tight_0847.txt
# Converted bounding_box_2d_tight_0848.npy to YOLO format and saved as bounding_box_2d_tight_0848.txt
# Converted bounding_box_2d_tight_0849.npy to YOLO format and saved as bounding_box_2d_tight_0849.txt
# Converted bounding_box_2d_tight_0850.npy to YOLO format and saved as bounding_box_2d_tight_0850.txt
# Converted bounding_box_2d_tight_0851.npy to YOLO format and saved as bounding_box_2d_tight_0851.txt
# Converted bounding_box_2d_tight_0852.npy to YOLO format and saved as bounding_box_2d_tight_0852.txt
# Converted bounding_box_2d_tight_0853.npy to YOLO format and saved as bounding_box_2d_tight_0853.txt
# Converted bounding_box_2d_tight_0854.npy to YOLO format and saved as bounding_box_2d_tight_0854.txt
# Converted bounding_box_2d_tight_0855.npy to YOLO format and saved as bounding_box_2d_tight_0855.txt
# Converted bounding_box_2d_tight_0856.npy to YOLO format and saved as bounding_box_2d_tight_0856.txt
# Converted bounding_box_2d_tight_0857.npy to YOLO format and saved as bounding_box_2d_tight_0857.txt
# Converted bounding_box_2d_tight_0858.npy to YOLO format and saved as bounding_box_2d_tight_0858.txt
# Converted bounding_box_2d_tight_0859.npy to YOLO format and saved as bounding_box_2d_tight_0859.txt
# Converted bounding_box_2d_tight_0860.npy to YOLO format and saved as bounding_box_2d_tight_0860.txt
# Converted bounding_box_2d_tight_0861.npy to YOLO format and saved as bounding_box_2d_tight_0861.txt
# Converted bounding_box_2d_tight_0862.npy to YOLO format and saved as bounding_box_2d_tight_0862.txt
# Converted bounding_box_2d_tight_0863.npy to YOLO format and saved as bounding_box_2d_tight_0863.txt
# Converted bounding_box_2d_tight_0864.npy to YOLO format and saved as bounding_box_2d_tight_0864.txt
# Converted bounding_box_2d_tight_0865.npy to YOLO format and saved as bounding_box_2d_tight_0865.txt
# Converted bounding_box_2d_tight_0866.npy to YOLO format and saved as bounding_box_2d_tight_0866.txt
# Converted bounding_box_2d_tight_0867.npy to YOLO format and saved as bounding_box_2d_tight_0867.txt
# Converted bounding_box_2d_tight_0868.npy to YOLO format and saved as bounding_box_2d_tight_0868.txt
# Converted bounding_box_2d_tight_0869.npy to YOLO format and saved as bounding_box_2d_tight_0869.txt
# Converted bounding_box_2d_tight_0870.npy to YOLO format and saved as bounding_box_2d_tight_0870.txt
# Converted bounding_box_2d_tight_0871.npy to YOLO format and saved as bounding_box_2d_tight_0871.txt
# Converted bounding_box_2d_tight_0872.npy to YOLO format and saved as bounding_box_2d_tight_0872.txt
# Converted bounding_box_2d_tight_0873.npy to YOLO format and saved as bounding_box_2d_tight_0873.txt
# Converted bounding_box_2d_tight_0874.npy to YOLO format and saved as bounding_box_2d_tight_0874.txt
# Converted bounding_box_2d_tight_0875.npy to YOLO format and saved as bounding_box_2d_tight_0875.txt
# Converted bounding_box_2d_tight_0876.npy to YOLO format and saved as bounding_box_2d_tight_0876.txt
# Converted bounding_box_2d_tight_0877.npy to YOLO format and saved as bounding_box_2d_tight_0877.txt
# Converted bounding_box_2d_tight_0878.npy to YOLO format and saved as bounding_box_2d_tight_0878.txt
# Converted bounding_box_2d_tight_0879.npy to YOLO format and saved as bounding_box_2d_tight_0879.txt
# Converted bounding_box_2d_tight_0880.npy to YOLO format and saved as bounding_box_2d_tight_0880.txt
# Converted bounding_box_2d_tight_0881.npy to YOLO format and saved as bounding_box_2d_tight_0881.txt
# Converted bounding_box_2d_tight_0882.npy to YOLO format and saved as bounding_box_2d_tight_0882.txt
# Converted bounding_box_2d_tight_0883.npy to YOLO format and saved as bounding_box_2d_tight_0883.txt
# Converted bounding_box_2d_tight_0884.npy to YOLO format and saved as bounding_box_2d_tight_0884.txt
# Converted bounding_box_2d_tight_0885.npy to YOLO format and saved as bounding_box_2d_tight_0885.txt
# Converted bounding_box_2d_tight_0886.npy to YOLO format and saved as bounding_box_2d_tight_0886.txt
# Converted bounding_box_2d_tight_0887.npy to YOLO format and saved as bounding_box_2d_tight_0887.txt
# Converted bounding_box_2d_tight_0888.npy to YOLO format and saved as bounding_box_2d_tight_0888.txt
# Converted bounding_box_2d_tight_0889.npy to YOLO format and saved as bounding_box_2d_tight_0889.txt
# Converted bounding_box_2d_tight_0890.npy to YOLO format and saved as bounding_box_2d_tight_0890.txt
# Converted bounding_box_2d_tight_0891.npy to YOLO format and saved as bounding_box_2d_tight_0891.txt
# Converted bounding_box_2d_tight_0892.npy to YOLO format and saved as bounding_box_2d_tight_0892.txt
# Converted bounding_box_2d_tight_0893.npy to YOLO format and saved as bounding_box_2d_tight_0893.txt
# Converted bounding_box_2d_tight_0894.npy to YOLO format and saved as bounding_box_2d_tight_0894.txt
# Converted bounding_box_2d_tight_0895.npy to YOLO format and saved as bounding_box_2d_tight_0895.txt
# Converted bounding_box_2d_tight_0896.npy to YOLO format and saved as bounding_box_2d_tight_0896.txt
# Converted bounding_box_2d_tight_0897.npy to YOLO format and saved as bounding_box_2d_tight_0897.txt
# Converted bounding_box_2d_tight_0898.npy to YOLO format and saved as bounding_box_2d_tight_0898.txt
# Converted bounding_box_2d_tight_0899.npy to YOLO format and saved as bounding_box_2d_tight_0899.txt
# Converted bounding_box_2d_tight_0900.npy to YOLO format and saved as bounding_box_2d_tight_0900.txt
# Converted bounding_box_2d_tight_0901.npy to YOLO format and saved as bounding_box_2d_tight_0901.txt
# Converted bounding_box_2d_tight_0902.npy to YOLO format and saved as bounding_box_2d_tight_0902.txt
# Converted bounding_box_2d_tight_0903.npy to YOLO format and saved as bounding_box_2d_tight_0903.txt
# Converted bounding_box_2d_tight_0904.npy to YOLO format and saved as bounding_box_2d_tight_0904.txt
# Converted bounding_box_2d_tight_0905.npy to YOLO format and saved as bounding_box_2d_tight_0905.txt
# Converted bounding_box_2d_tight_0906.npy to YOLO format and saved as bounding_box_2d_tight_0906.txt
# Converted bounding_box_2d_tight_0907.npy to YOLO format and saved as bounding_box_2d_tight_0907.txt
# Converted bounding_box_2d_tight_0908.npy to YOLO format and saved as bounding_box_2d_tight_0908.txt
# Converted bounding_box_2d_tight_0909.npy to YOLO format and saved as bounding_box_2d_tight_0909.txt
# Converted bounding_box_2d_tight_0910.npy to YOLO format and saved as bounding_box_2d_tight_0910.txt
# Converted bounding_box_2d_tight_0911.npy to YOLO format and saved as bounding_box_2d_tight_0911.txt
# Converted bounding_box_2d_tight_0912.npy to YOLO format and saved as bounding_box_2d_tight_0912.txt
# Converted bounding_box_2d_tight_0913.npy to YOLO format and saved as bounding_box_2d_tight_0913.txt
# Converted bounding_box_2d_tight_0914.npy to YOLO format and saved as bounding_box_2d_tight_0914.txt
# Converted bounding_box_2d_tight_0915.npy to YOLO format and saved as bounding_box_2d_tight_0915.txt
# Converted bounding_box_2d_tight_0916.npy to YOLO format and saved as bounding_box_2d_tight_0916.txt
# Converted bounding_box_2d_tight_0917.npy to YOLO format and saved as bounding_box_2d_tight_0917.txt
# Converted bounding_box_2d_tight_0918.npy to YOLO format and saved as bounding_box_2d_tight_0918.txt
# Converted bounding_box_2d_tight_0919.npy to YOLO format and saved as bounding_box_2d_tight_0919.txt
# Converted bounding_box_2d_tight_0920.npy to YOLO format and saved as bounding_box_2d_tight_0920.txt
# Converted bounding_box_2d_tight_0921.npy to YOLO format and saved as bounding_box_2d_tight_0921.txt
# Converted bounding_box_2d_tight_0922.npy to YOLO format and saved as bounding_box_2d_tight_0922.txt
# Converted bounding_box_2d_tight_0923.npy to YOLO format and saved as bounding_box_2d_tight_0923.txt
# Converted bounding_box_2d_tight_0924.npy to YOLO format and saved as bounding_box_2d_tight_0924.txt
# Converted bounding_box_2d_tight_0925.npy to YOLO format and saved as bounding_box_2d_tight_0925.txt
# Converted bounding_box_2d_tight_0926.npy to YOLO format and saved as bounding_box_2d_tight_0926.txt
# Converted bounding_box_2d_tight_0927.npy to YOLO format and saved as bounding_box_2d_tight_0927.txt
# Converted bounding_box_2d_tight_0928.npy to YOLO format and saved as bounding_box_2d_tight_0928.txt
# Converted bounding_box_2d_tight_0929.npy to YOLO format and saved as bounding_box_2d_tight_0929.txt
# Converted bounding_box_2d_tight_0930.npy to YOLO format and saved as bounding_box_2d_tight_0930.txt
# Converted bounding_box_2d_tight_0931.npy to YOLO format and saved as bounding_box_2d_tight_0931.txt
# Converted bounding_box_2d_tight_0932.npy to YOLO format and saved as bounding_box_2d_tight_0932.txt
# Converted bounding_box_2d_tight_0933.npy to YOLO format and saved as bounding_box_2d_tight_0933.txt
# Converted bounding_box_2d_tight_0934.npy to YOLO format and saved as bounding_box_2d_tight_0934.txt
# Converted bounding_box_2d_tight_0935.npy to YOLO format and saved as bounding_box_2d_tight_0935.txt
# Converted bounding_box_2d_tight_0936.npy to YOLO format and saved as bounding_box_2d_tight_0936.txt
# Converted bounding_box_2d_tight_0937.npy to YOLO format and saved as bounding_box_2d_tight_0937.txt
# Converted bounding_box_2d_tight_0938.npy to YOLO format and saved as bounding_box_2d_tight_0938.txt
# Converted bounding_box_2d_tight_0939.npy to YOLO format and saved as bounding_box_2d_tight_0939.txt
# Converted bounding_box_2d_tight_0940.npy to YOLO format and saved as bounding_box_2d_tight_0940.txt
# Converted bounding_box_2d_tight_0941.npy to YOLO format and saved as bounding_box_2d_tight_0941.txt
# Converted bounding_box_2d_tight_0942.npy to YOLO format and saved as bounding_box_2d_tight_0942.txt
# Converted bounding_box_2d_tight_0943.npy to YOLO format and saved as bounding_box_2d_tight_0943.txt
# Converted bounding_box_2d_tight_0944.npy to YOLO format and saved as bounding_box_2d_tight_0944.txt
# Converted bounding_box_2d_tight_0945.npy to YOLO format and saved as bounding_box_2d_tight_0945.txt
# Converted bounding_box_2d_tight_0946.npy to YOLO format and saved as bounding_box_2d_tight_0946.txt
# Converted bounding_box_2d_tight_0947.npy to YOLO format and saved as bounding_box_2d_tight_0947.txt
# Converted bounding_box_2d_tight_0948.npy to YOLO format and saved as bounding_box_2d_tight_0948.txt
# Converted bounding_box_2d_tight_0949.npy to YOLO format and saved as bounding_box_2d_tight_0949.txt
# Converted bounding_box_2d_tight_0950.npy to YOLO format and saved as bounding_box_2d_tight_0950.txt
# Converted bounding_box_2d_tight_0951.npy to YOLO format and saved as bounding_box_2d_tight_0951.txt
# Converted bounding_box_2d_tight_0952.npy to YOLO format and saved as bounding_box_2d_tight_0952.txt
# Converted bounding_box_2d_tight_0953.npy to YOLO format and saved as bounding_box_2d_tight_0953.txt
# Converted bounding_box_2d_tight_0954.npy to YOLO format and saved as bounding_box_2d_tight_0954.txt
# Converted bounding_box_2d_tight_0955.npy to YOLO format and saved as bounding_box_2d_tight_0955.txt
# Converted bounding_box_2d_tight_0956.npy to YOLO format and saved as bounding_box_2d_tight_0956.txt
# Converted bounding_box_2d_tight_0957.npy to YOLO format and saved as bounding_box_2d_tight_0957.txt
# Converted bounding_box_2d_tight_0958.npy to YOLO format and saved as bounding_box_2d_tight_0958.txt
# Converted bounding_box_2d_tight_0959.npy to YOLO format and saved as bounding_box_2d_tight_0959.txt
# Converted bounding_box_2d_tight_0960.npy to YOLO format and saved as bounding_box_2d_tight_0960.txt
# Converted bounding_box_2d_tight_0961.npy to YOLO format and saved as bounding_box_2d_tight_0961.txt
# Converted bounding_box_2d_tight_0962.npy to YOLO format and saved as bounding_box_2d_tight_0962.txt
# Converted bounding_box_2d_tight_0963.npy to YOLO format and saved as bounding_box_2d_tight_0963.txt
# Converted bounding_box_2d_tight_0964.npy to YOLO format and saved as bounding_box_2d_tight_0964.txt
# Converted bounding_box_2d_tight_0965.npy to YOLO format and saved as bounding_box_2d_tight_0965.txt
# Converted bounding_box_2d_tight_0966.npy to YOLO format and saved as bounding_box_2d_tight_0966.txt
# Converted bounding_box_2d_tight_0967.npy to YOLO format and saved as bounding_box_2d_tight_0967.txt
# Converted bounding_box_2d_tight_0968.npy to YOLO format and saved as bounding_box_2d_tight_0968.txt
# Converted bounding_box_2d_tight_0969.npy to YOLO format and saved as bounding_box_2d_tight_0969.txt
# Converted bounding_box_2d_tight_0970.npy to YOLO format and saved as bounding_box_2d_tight_0970.txt
# Converted bounding_box_2d_tight_0971.npy to YOLO format and saved as bounding_box_2d_tight_0971.txt
# Converted bounding_box_2d_tight_0972.npy to YOLO format and saved as bounding_box_2d_tight_0972.txt
# Converted bounding_box_2d_tight_0973.npy to YOLO format and saved as bounding_box_2d_tight_0973.txt
# Converted bounding_box_2d_tight_0974.npy to YOLO format and saved as bounding_box_2d_tight_0974.txt
# Converted bounding_box_2d_tight_0975.npy to YOLO format and saved as bounding_box_2d_tight_0975.txt
# Converted bounding_box_2d_tight_0976.npy to YOLO format and saved as bounding_box_2d_tight_0976.txt
# Converted bounding_box_2d_tight_0977.npy to YOLO format and saved as bounding_box_2d_tight_0977.txt
# Converted bounding_box_2d_tight_0978.npy to YOLO format and saved as bounding_box_2d_tight_0978.txt
# Converted bounding_box_2d_tight_0979.npy to YOLO format and saved as bounding_box_2d_tight_0979.txt
# Converted bounding_box_2d_tight_0980.npy to YOLO format and saved as bounding_box_2d_tight_0980.txt
# Converted bounding_box_2d_tight_0981.npy to YOLO format and saved as bounding_box_2d_tight_0981.txt
# Converted bounding_box_2d_tight_0982.npy to YOLO format and saved as bounding_box_2d_tight_0982.txt
# Converted bounding_box_2d_tight_0983.npy to YOLO format and saved as bounding_box_2d_tight_0983.txt
# Converted bounding_box_2d_tight_0984.npy to YOLO format and saved as bounding_box_2d_tight_0984.txt
# Converted bounding_box_2d_tight_0985.npy to YOLO format and saved as bounding_box_2d_tight_0985.txt
# Converted bounding_box_2d_tight_0986.npy to YOLO format and saved as bounding_box_2d_tight_0986.txt
# Converted bounding_box_2d_tight_0987.npy to YOLO format and saved as bounding_box_2d_tight_0987.txt
# Converted bounding_box_2d_tight_0988.npy to YOLO format and saved as bounding_box_2d_tight_0988.txt
# Converted bounding_box_2d_tight_0989.npy to YOLO format and saved as bounding_box_2d_tight_0989.txt
# Converted bounding_box_2d_tight_0990.npy to YOLO format and saved as bounding_box_2d_tight_0990.txt
# Converted bounding_box_2d_tight_0991.npy to YOLO format and saved as bounding_box_2d_tight_0991.txt
# Converted bounding_box_2d_tight_0992.npy to YOLO format and saved as bounding_box_2d_tight_0992.txt
# Converted bounding_box_2d_tight_0993.npy to YOLO format and saved as bounding_box_2d_tight_0993.txt
# Converted bounding_box_2d_tight_0994.npy to YOLO format and saved as bounding_box_2d_tight_0994.txt
# Converted bounding_box_2d_tight_0995.npy to YOLO format and saved as bounding_box_2d_tight_0995.txt
# Converted bounding_box_2d_tight_0996.npy to YOLO format and saved as bounding_box_2d_tight_0996.txt
# Converted bounding_box_2d_tight_0997.npy to YOLO format and saved as bounding_box_2d_tight_0997.txt
# Converted bounding_box_2d_tight_0998.npy to YOLO format and saved as bounding_box_2d_tight_0998.txt
# Converted bounding_box_2d_tight_0999.npy to YOLO format and saved as bounding_box_2d_tight_0999.txt

# %%
import cv2

def draw_yolo_bbox(image_path, bbox, class_id=None, label=None, color=(0, 255, 0), thickness=2):
    """
    Draw a bounding box on an image using YOLO format.

    :param image_path: Path to the image file.
    :param bbox: YOLO format bounding box [x_center, y_center, width, height] with normalized values.
    :param class_id: (Optional) Class ID of the object.
    :param label: (Optional) Text label to display on the bounding box.
    :param color: Bounding box color in BGR format.
    :param thickness: Thickness of the bounding box lines.
    """
    # Load the image
    image = cv2.imread(image_path)
    height, width, _ = image.shape

    # YOLO format bbox to absolute values
    x_center, y_center, box_width, box_height = bbox
    x_center = int(x_center * width)
    y_center = int(y_center * height)
    box_width = int(box_width * width)
    box_height = int(box_height * height)

    # Calculate the top-left and bottom-right corners of the bounding box
    x_min = int(x_center - (box_width / 2))
    y_min = int(y_center - (box_height / 2))
    x_max = int(x_center + (box_width / 2))
    y_max = int(y_center + (box_height / 2))

    # Draw the bounding box
    cv2.rectangle(image, (x_min, y_min), (x_max, y_max), color, thickness)

    # If a label is provided, display it
    if label:
        label_text = f"{label} ({class_id})" if class_id is not None else label
        cv2.putText(image, label_text, (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    # Display the image with the bounding box
    cv2.imshow('Image with Bounding Box', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Example usage
image_path = "C:\\Users\\georg\\Desktop\\train_imgs\\rgb_0001.png"
bbox = [0.921484375, 0.8812500000000001, 0.08046875, 0.07083333333333333]  # Example YOLO bbox [x_center, y_center, width, height] in normalized values
class_id = 1  # Example class ID
label = "ExampleObject"  # Example label

draw_yolo_bbox(image_path, bbox, class_id=class_id, label=label)
